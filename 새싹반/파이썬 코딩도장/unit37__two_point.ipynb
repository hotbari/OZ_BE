# %%
class Point2D:
    def __init__(self, x, y):
        self.x = x
        self.y = y
 
p1 = Point2D(x=30, y=20)    # 점1
p2 = Point2D(x=60, y=50)    # 점2
 
print('p1: {} {}'.format(p1.x, p1.y))    # 30 20
print('p2: {} {}'.format(p2.x, p2.y))
# Out:
# p1: 30 20
# p2: 60 50

# %% [markdown]
# namedtuple 을 사용하여 두 점의 거리 구하기

# %%
import math
import collections

# 두 점을 표현
# 클래스 = collections.namedtuple('자료형이름', ['요소이름1','요소이름2])
Point2D = collections.namedtuple('Point2D',['x','y'])

p1 = Point2D(x=30, y=20)
p2 = Point2D(x=60, y=50)

a = p1.x - p2.x
b = p1.y - p2.y

c = math.sqrt( (a*a)+(b*b) )
print(c)
# Out:
# 42.42640687119285

# %% [markdown]
# 사각형의 넓이 구하기

# %%
class Rectangle:
    def __init__(self, x1, y1, x2, y2):
        self.x1 = x1
        self.y1 = y1
        self.x2 = x2
        self.y2 = y2

rect = Rectangle(x1=20, y1=20, x2=40, y2=30)

area = (rect.x2 - rect.x1) * (rect.y2 - rect.y1)
# abs를 사용하면 음수 문제 해결 가능 abs(rect.x2-rect.x1)                            
print(area)
# Out:
# 200

# %% [markdown]
# 표준 입력으로 x, y 좌표 4개가 입력되어 Point2D 클래스의 인스턴스 리스트에 저장됩니다. 여기서 점 4개는 첫 번째 점부터 마지막 점까지 순서대로 이어져 있습니다. 다음 소스 코드를 완성하여 첫 번째 점부터 마지막 점까지 연결된 선의 길이가 출력되게 만드세요.

# %%
import math

class Point2D:
    def __init__(self, x=0, y=0):
        self.x = x
        self.y = y

length = 0.0
p = [Point2D(), Point2D(), Point2D(), Point2D()]
p[0].x, p[0].y, p[1].x, p[1].y, p[2].x, p[2].y, p[3].x, p[3].y = map(int, input().split())

# 선분 길이 구하기

a = p[0].x - p[1].x
aa = p[0].y - p[1].y

b = p[1].x - p[2].x
bb = p[1].y - p[2].y

c = p[2].x - p[3].x
cc = p[2].y - p[3].y

# 대각선 길이 구하기

line1 = math.sqrt( (a*a)+(aa*aa) )
line2 = math.sqrt( (b*b)+(bb*bb))
line3 = math.sqrt( (c*c)+(cc*cc))

length = line1+line2+line3


print(length)
# Out:
# 42.42640687119285

# %%
import math

class Point2D:
    def __init__(self, x=0, y=0):
        self.x = x
        self.y = y

length = 0.0
p = [Point2D(), Point2D(), Point2D(), Point2D()]
p[0].x, p[0].y, p[1].x, p[1].y, p[2].x, p[2].y, p[3].x, p[3].y = map(int, input().split())

# 선분 길이 구하기 for문으로
for i in range (len(p)-1):
    weight = p[i].x - p[i+1].x
    height = p[i].y - p[i+1].y
    result = math.sqrt( math.pow(weight,2) + math.pow(height,2) )
    length += result
    


print(length)
# Out:
# 42.42640687119285

# %% [markdown]
# 덕 타이핑

# %%
class Duck :
    def quack(self): print('rr')
    def feathers(self): print('Duck has white and gray feathers')
    
class Person:
    def quack(self): print('Person said qq')
    def feathers(self): print('people land feaht show')
    
def in_the_forest(duck): #
